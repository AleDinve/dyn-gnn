# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from wl_test import dyn_wl_generator

# %%
A = np.loadtxt('graphs/graph9.txt').astype(int)
G = nx.from_numpy_matrix(A)
nx.draw_networkx(G)

# %%
a = dyn_wl_generator()

# %%
for data in a:
    print(a)

# %%
seq_len_list = [4,5,6]
for seq_len in seq_len_list:
    data = pd.read_csv('dynamics.csv')
    data = data[data['Number of timestamps']==seq_len]
    plot = sns.lineplot(data=data, x='Epoch', y='Train loss', hue='GNN hidden dimension')
    plot.figure.savefig('pics/approx_timelength_'+str(seq_len)+'.png')
    plt.close()
